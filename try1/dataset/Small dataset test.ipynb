# %%
import os
import os.path as osp
import numpy as np
import random
import collections
import torch
import torchvision
import cv2
from torch.utils import data

from PIL import Image, ImageOps

# %%
class SmallCSDatset(data.Dataset):
    def __init__(self, path="data/small_cityscapes/cityscapes/train"):
        self.path = path
        list_files = os.listdir(path)

    def __len__():
        return len(list_files)

    def __getitem(self, index):
        file = list_files[index]
        image_file = cv2.imread(self.path+file)
        image = ImageOps.crop(image, (0, 0, 256, 0))
        label = ImageOps.crop(image, (256, 0, 0, 0))

        return image, label

# %%
path = "data/small_cityscapes/cityscapes/train"

# %%
list_files = os.listdir(path)

# %%
list_files[0]
# Out:
# '2725.jpg'

# %%
filename = list_files[0]
image_file = Image.open(os.path.join(path, filename))
image = ImageOps.crop(image_file, (0, 0, 256, 0))
label = ImageOps.crop(image_file, (256, 0, 0, 0))

# %%
from matplotlib import pyplot as plt

# %%
print(label)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F38D0224438>

# %%
plt.imshow(label)
